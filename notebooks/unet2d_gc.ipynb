# %%
# !nvidia-smi -L
# Out:
# GPU 0: Tesla P4 (UUID: GPU-240b1391-9d21-3fd4-2fba-d6e24bf276f9)

# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# Mounting successful. Locate the dataset directory and create data generator

# %%
ROOT_DIR = "/content/gdrive/MyDrive/Brats_dataset"
import os
os.listdir(ROOT_DIR)
# Out:
# ['MICCAI_BraTS2020_TrainingData']

# %%
from tqdm import tqdm
import os


import numpy as np

import nibabel as nib
import matplotlib.pyplot as plt

import tensorflow as tf

from tensorflow.keras import backend as K

from tensorflow.keras import Input
from tensorflow.keras import initializers

from tensorflow.keras.layers import (
    Conv2D,
    Conv2DTranspose, 
    BatchNormalization, 
    Activation, 
    MaxPooling2D, 
    UpSampling2D, 
    concatenate, 
    Add,
    Dropout)



from skimage.transform import resize
from skimage import exposure
import cv2

from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping
from tensorflow.keras.optimizers import Adam

from tensorflow.keras.models import Model, load_model

# %matplotlib inline

# %%
def read_image(path):
    image = nib.load(path)
    image = (image.dataobj)
    return np.asarray(image)

# %%
TRAIN_DATA_PATH = os.path.join(ROOT_DIR, "MICCAI_BraTS2020_TrainingData")

case_id = '001'
case_path = os.path.join(TRAIN_DATA_PATH, f"BraTS20_Training_{case_id}")


flair_voxel = read_image(os.path.join(case_path, f'BraTS20_Training_{case_id}_flair.nii.gz'))
plt.imshow(flair_voxel[..., 60])

# %%
import random
def show_slice(case: str, mode: str, slice_: int = None):
  """
  case : str, three digit index from 001 to 369
  slice_: int, integer slice index ranging from 0 to 154
  mode: str, mode of image, can be one of the five following types (case sensitive)
  - flair
  - t1
  - t1ce
  - t2
  - seg
  """
  case_path = os.path.join(TRAIN_DATA_PATH, f'BraTS20_Training_{case}')
  voxel_path = os.path.join(case_path, f'BraTS20_Training_{case}_{mode}.nii.gz')
  voxel = read_image(voxel_path)
  if slice_ is None: 
    slice_ = random.randint(0, 156)
    
  img = voxel[..., slice_]
  plt.imshow(img, cmap="gray")
  return img

# %% [markdown]
# So far everything works fine on the google colab.

# %%
img = show_slice(case='120', mode='flair', slice_=20)

# %%
class DataGenerator(tf.keras.utils.Sequence):
    'Generates data for Keras'
    def __init__(self, spatient_IDs, dim=(128,128), start_slice = 20, z_range = 120, batch_size = 1, n_channels = 4, shuffle=True):
        'Initialization'
        self.dim = dim
        self.batch_size = batch_size
        self.list_IDs = spatient_IDs
        self.n_channels = n_channels
        self.shuffle = shuffle
        self.__start_slice = start_slice
        self.__z_range = z_range
        self.on_epoch_end()

    def __len__(self):
        'Denotes the number of batches per epoch'
        return int(np.floor(len(self.list_IDs) / self.batch_size))

    def __getitem__(self, index):
        'Generate one batch of data'
        # Generate indexes of the batch
        indexes = self.indexes[index*self.batch_size:(index+1)*self.batch_size]

        # Find list of IDs
        Batch_ids = [self.list_IDs[k] for k in indexes]

        # Generate data
        X, y = self.__data_generation(Batch_ids)

        return X, y

    def on_epoch_end(self):
        'Updates indexes after each epoch'
        self.indexes = np.arange(len(self.list_IDs))
        if self.shuffle == True:
            np.random.shuffle(self.indexes)

    def __data_generation(self, Batch_ids):
        'Generates data containing batch_size samples' # X : (n_samples, *dim, n_channels)
        # Initialization
        X = np.zeros((self.batch_size * self.__z_range, *self.dim, self.n_channels))
        y = np.zeros((self.batch_size * self.__z_range, 240, 240))
        Y = np.zeros((self.batch_size * self.__z_range, *self.dim, 4))


        
        # Generate data
        
        # Output is input image (normalized) & label as one-hot vector [a, b, c, d]
        # a --> not tumour (for 0 pixels)
        # b --> necrotic (for 1 pixels)
        # c --> edema (for 2 pixels)
        # d --> 


        for c, i in enumerate(Batch_ids):
            case_path = os.path.join(TRAIN_DATA_PATH, i)

            flair_path = os.path.join(case_path, f'{i}_flair.nii.gz')
            flair =read_image(flair_path)      

            t1_path = os.path.join(case_path, f'{i}_t1.nii.gz')
            t1 =read_image(t1_path)

            t1ce_path = os.path.join(case_path, f'{i}_t1ce.nii.gz')
            ce =read_image(t1ce_path)
            
            t2_path = os.path.join(case_path, f'{i}_t2.nii.gz')
            t2 =read_image(t2_path)

            seg_path = os.path.join(case_path, f'{i}_seg.nii.gz')
            seg =read_image(seg_path)
        
            for j in range(self.__z_range):
                X[j + self.__z_range * c, :, :, 0] = cv2.resize(flair[:, :, j + self.__start_slice], self.dim)
                X[j + self.__z_range * c, :, :, 1] = cv2.resize(t1[:, :, j + self.__start_slice], self.dim)
                X[j + self.__z_range * c, :, :, 2] = cv2.resize(ce[:, :, j + self.__start_slice], self.dim)
                X[j + self.__z_range * c, :, :, 3] = cv2.resize(t2[:, :, j + self.__start_slice], self.dim)

                y[j + self.__z_range * c] = seg[:, :, j + self.__start_slice];
                    
            #=============Preprocess masks===========
        y[ y == 4 ] = 3;
        mask = tf.one_hot(y, 4);
        Y = tf.image.resize(mask, self.dim)

        # X = cv2.normalize(X, None, alpha=0, beta=255, norm_type = cv2.NORM_MINMAX, dtype = cv2.CV_32F)
        return X/np.max(X), Y

# %%
from sklearn.model_selection import train_test_split
# lists of directories with studies
train_and_val_directories = [f.path for f in os.scandir(TRAIN_DATA_PATH) if f.is_dir()]
# file BraTS20_Training_355 has ill formatted name for for seg.nii file
train_and_val_directories.remove(os.path.join(TRAIN_DATA_PATH, 'BraTS20_Training_355'))


def pathListIntoIds(dirList):
    x = []
    for i in range(0,len(dirList)):
        x.append(dirList[i][dirList[i].rfind('/')+1:])
    return x

train_and_test_ids = pathListIntoIds(train_and_val_directories); 

train_val_ids, test_ids = train_test_split(train_and_test_ids,test_size=0.15, shuffle=True) 
train_ids, val_ids = train_test_split(train_val_ids,test_size=0.2, shuffle=True) 

print(f"train size: {len(train_ids)}, validation size: {len(val_ids)}, test size: {len(test_ids)}")
# Out:
# train size: 249, validation size: 63, test size: 56

# %%
train_gen = DataGenerator(train_ids)
valid_gen = DataGenerator(val_ids)
test_gen = DataGenerator(test_ids)

# %%
X, y = train_gen[0]

y.shape
# Out:
# TensorShape([120, 128, 128, 4])

# %% [markdown]
# ### Model creation, Unet 2D with minor adjustments
#
# Instead of using Unet 2D baseline, we can use some altercations.
# 1. Use dropout layers in between.
# 2. Use elementwise sum instead of channelwise concatenation
# 3. Use dice loss instead of categorical crossentropy

# %%
# metrics

def dice_coef(y_true, y_pred, smooth=1.0):
    ''' Dice Coefficient
    Args:
        y_true (np.array): Ground Truth Heatmap (Label)
        y_pred (np.array): Prediction Heatmap
    '''

    class_num = 2
    for i in range(class_num):
        y_true_f = K.flatten(y_true[:,:,:,i])
        y_pred_f = K.flatten(y_pred[:,:,:,i])
        intersection = K.sum(y_true_f * y_pred_f)
        loss = ((2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth))
        if i == 0:
            total_loss = loss
        else:
            total_loss = total_loss + loss
    total_loss = total_loss / class_num
    return total_loss

def dice_coef_loss(y_true, y_pred):
    ''' Dice Coefficient Loss
    Args:
        y_true (np.array): Ground Truth Heatmap (Label)
        y_pred (np.array): Prediction Heatmap
    '''
    return 1-dice_coef(y_true, y_pred)

# %%
X, y = train_gen[0]
iou = tf.metrics.MeanIoU(num_classes=4)
iou(y, y)
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=1.0>

# %%
def build_unet_baseline(inputs, ker_init, dropout):
    conv1 = Conv2D(32, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(inputs)
    conv1 = Conv2D(32, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv1)

    pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)

    conv2 = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(pool1)
    conv2 = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv2)

    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)

    conv3 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(pool2)
    conv3 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv3)

    pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)

    conv4 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(pool3)
    conv4 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv4)

    pool4 = MaxPooling2D(pool_size=(2, 2))(conv4)

    conv5 = Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(pool4)
    conv5 = Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv5)
    
    up6 = concatenate([Conv2DTranspose(256, (2, 2), strides=(2, 2), padding='same',
                kernel_initializer=ker_init)(conv5),conv4], axis=3)
    

    conv6 = Conv2D(256, (3, 3), activation='relu', padding='same',
                   kernel_initializer=ker_init)(up6)

    conv6 = Conv2D(256, (3, 3), activation='relu', padding='same',
                   kernel_initializer=ker_init)(conv6)

    up7 = concatenate([Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same',
                kernel_initializer=ker_init)(conv6), conv3], axis=3)

    conv7 = Conv2D(128, (3, 3), activation='relu', padding='same',
                   kernel_initializer=ker_init)(up7)

    conv7 = Conv2D(128, (3, 3), activation='relu', padding='same',
                   kernel_initializer=ker_init)(conv7)

    up8 = concatenate([Conv2DTranspose(64, (2, 2), strides=(2, 2),padding='same',
                kernel_initializer=ker_init)(conv7), conv2], axis=3)
    
    conv8 = Conv2D(64, (3, 3), activation='relu', padding='same',
                   kernel_initializer=ker_init)(up8)

    conv8 = Conv2D(64, (3, 3), activation='relu', padding='same',
                   kernel_initializer=ker_init)(conv8)

    up9 = concatenate([Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same',
                kernel_initializer=ker_init)(conv8), conv1], axis=3)
    

    conv9 = Conv2D(32, (3, 3), activation='relu', padding='same',
                   kernel_initializer=ker_init)(up9)

    conv9 = Conv2D(32, (3, 3), activation='relu', padding='same',
                   kernel_initializer=ker_init)(conv9)

    conv10 = Conv2D(4, (1, 1), activation='relu',
                    kernel_initializer=ker_init)(conv9)
                    
    conv10 = Activation('softmax')(conv10)
    
    return Model(inputs = inputs, outputs = conv10)

# %%
K.clear_session()

# %%
input_layer = Input((128, 128, 4))

ker_init = 'he_normal'
# ker_init = initializers.random_normal(stddev=0.01)

unet_baseline = build_unet_baseline(input_layer, ker_init, 0.2)
unet_baseline.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 128, 128, 4) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 128, 128, 32) 1184        input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 128, 128, 32) 9248        conv2d[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 64, 64, 32)   0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 64, 64, 64)   18496       max_pooling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 64, 64, 64)   36928       conv2d_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 32, 32, 64)   0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 32, 32, 128)  73856       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 32, 32, 128)  147584      conv2d_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 16, 16, 128)  0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 16, 16, 256)  295168      max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 16, 16, 256)  590080      conv2d_6[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 8, 8, 256)    0           conv2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 8, 8, 512)    1180160     max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 8, 8, 512)    2359808     conv2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose (Conv2DTranspo (None, 16, 16, 256)  524544      conv2d_9[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 16, 16, 512)  0           conv2d_transpose[0][0]
#                                                                  conv2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 16, 16, 256)  1179904     concatenate[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 16, 16, 256)  590080      conv2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 32, 32, 128)  131200      conv2d_11[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 32, 32, 256)  0           conv2d_transpose_1[0][0]
#                                                                  conv2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 32, 32, 128)  295040      concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 32, 32, 128)  147584      conv2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 64, 64, 64)   32832       conv2d_13[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 64, 64, 128)  0           conv2d_transpose_2[0][0]
#                                                                  conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 64, 64, 64)   73792       concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 64, 64, 64)   36928       conv2d_14[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 128, 128, 32) 8224        conv2d_15[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 128, 128, 64) 0           conv2d_transpose_3[0][0]
#                                                                  conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 128, 128, 32) 18464       concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 128, 128, 32) 9248        conv2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 128, 128, 4)  132         conv2d_17[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 128, 128, 4)  0           conv2d_18[0][0]
# ==================================================================================================
# Total params: 7,760,484
# Trainable params: 7,760,484
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
def plot_model(model_obj: tf.keras.Model, filename: str):
    return tf.keras.utils.plot_model(
        model_obj,
        to_file=filename,
        show_shapes=True,
        show_dtype=False,
        show_layer_names=True,
        rankdir="TB",
        expand_nested=False,
        dpi=70,
    )

# %%
plot_model(unet_baseline, filename="unet_baseline.jpg")

# %%
unet_baseline.compile(
    optimizer = tf.keras.optimizers.Adam(learning_rate=1e-04), 
                    loss = 'categorical_crossentropy', 
                    metrics = ["accuracy", dice_coef, tf.metrics.MeanIoU(num_classes=4)]
)

# %%
from tensorflow.keras.callbacks import CSVLogger
csv_logger = CSVLogger('training_unet2d_baseline_new.csv', separator=',', append=True)
checkpoint_filepath = 'unet2d_baseline.h5'

model_checkpoint = tf.keras.callbacks.ModelCheckpoint( 
    filepath=checkpoint_filepath,
    monitor="val_loss",
    verbose=0,
    save_best_only=True,
    save_weights_only=True)

callbacks = [
    ReduceLROnPlateau(monitor="val_loss", patience=10, factor=0.2, verbose=1, min_lr=1e-06),
    csv_logger,
    model_checkpoint
]

# %%
results = unet_baseline.fit(
    train_gen,
    epochs=50,
    steps_per_epoch=len(train_ids),  
    validation_data = valid_gen,
    callbacks= callbacks
)
# Out:
# Epoch 1/50
# 249/249 [==============================] - 944s 4s/step - loss: 0.1191 - accuracy: 0.9820 - dice_coef: 0.4981 - mean_io_u: 0.5909 - val_loss: 0.0565 - val_accuracy: 0.9859 - val_dice_coef: 0.5162 - val_mean_io_u: 0.5779
# Epoch 2/50
# 249/249 [==============================] - 218s 875ms/step - loss: 0.0536 - accuracy: 0.9856 - dice_coef: 0.5362 - mean_io_u: 0.6532 - val_loss: 0.0403 - val_accuracy: 0.9862 - val_dice_coef: 0.5497 - val_mean_io_u: 0.6493
# Epoch 3/50
# 249/249 [==============================] - 218s 875ms/step - loss: 0.0401 - accuracy: 0.9869 - dice_coef: 0.5587 - mean_io_u: 0.7021 - val_loss: 0.0376 - val_accuracy: 0.9881 - val_dice_coef: 0.5557 - val_mean_io_u: 0.7305
# Epoch 4/50
# 249/249 [==============================] - 217s 871ms/step - loss: 0.0366 - accuracy: 0.9882 - dice_coef: 0.5638 - mean_io_u: 0.7225 - val_loss: 0.0331 - val_accuracy: 0.9887 - val_dice_coef: 0.5763 - val_mean_io_u: 0.7118
# Epoch 5/50
# 249/249 [==============================] - 217s 871ms/step - loss: 0.0363 - accuracy: 0.9884 - dice_coef: 0.5741 - mean_io_u: 0.7474 - val_loss: 0.0300 - val_accuracy: 0.9895 - val_dice_coef: 0.5898 - val_mean_io_u: 0.7800
# Epoch 6/50
# 249/249 [==============================] - 217s 870ms/step - loss: 0.0331 - accuracy: 0.9889 - dice_coef: 0.5820 - mean_io_u: 0.7550 - val_loss: 0.0301 - val_accuracy: 0.9897 - val_dice_coef: 0.5925 - val_mean_io_u: 0.7714
# Epoch 7/50
# 249/249 [==============================] - 217s 870ms/step - loss: 0.0313 - accuracy: 0.9894 - dice_coef: 0.5843 - mean_io_u: 0.7498 - val_loss: 0.0309 - val_accuracy: 0.9889 - val_dice_coef: 0.5915 - val_mean_io_u: 0.7295
# Epoch 8/50
# 249/249 [==============================] - 217s 871ms/step - loss: 0.0301 - accuracy: 0.9896 - dice_coef: 0.5894 - mean_io_u: 0.7733 - val_loss: 0.0306 - val_accuracy: 0.9898 - val_dice_coef: 0.5909 - val_mean_io_u: 0.7948
# Epoch 9/50
# 249/249 [==============================] - 217s 868ms/step - loss: 0.0291 - accuracy: 0.9899 - dice_coef: 0.5922 - mean_io_u: 0.7377 - val_loss: 0.0298 - val_accuracy: 0.9898 - val_dice_coef: 0.5926 - val_mean_io_u: 0.7726
# Epoch 10/50
# 249/249 [==============================] - 217s 869ms/step - loss: 0.0282 - accuracy: 0.9902 - dice_coef: 0.5955 - mean_io_u: 0.7746 - val_loss: 0.0269 - val_accuracy: 0.9902 - val_dice_coef: 0.6050 - val_mean_io_u: 0.7901
# Epoch 11/50
# 249/249 [==============================] - 217s 869ms/step - loss: 0.0267 - accuracy: 0.9905 - dice_coef: 0.6004 - mean_io_u: 0.7853 - val_loss: 0.0329 - val_accuracy: 0.9887 - val_dice_coef: 0.5847 - val_mean_io_u: 0.7384
# Epoch 12/50
# 249/249 [==============================] - 217s 869ms/step - loss: 0.0269 - accuracy: 0.9905 - dice_coef: 0.5995 - mean_io_u: 0.7472 - val_loss: 0.0274 - val_accuracy: 0.9897 - val_dice_coef: 0.6247 - val_mean_io_u: 0.7910
# Epoch 13/50
# 249/249 [==============================] - 219s 877ms/step - loss: 0.0257 - accuracy: 0.9908 - dice_coef: 0.6054 - mean_io_u: 0.7881 - val_loss: 0.0257 - val_accuracy: 0.9910 - val_dice_coef: 0.6072 - val_mean_io_u: 0.7714
# Epoch 14/50
# 249/249 [==============================] - 216s 868ms/step - loss: 0.0249 - accuracy: 0.9911 - dice_coef: 0.6029 - mean_io_u: 0.7837 - val_loss: 0.0243 - val_accuracy: 0.9908 - val_dice_coef: 0.6219 - val_mean_io_u: 0.7723
# Epoch 15/50
# 249/249 [==============================] - 217s 869ms/step - loss: 0.0247 - accuracy: 0.9913 - dice_coef: 0.6103 - mean_io_u: 0.7657 - val_loss: 0.0234 - val_accuracy: 0.9917 - val_dice_coef: 0.6150 - val_mean_io_u: 0.7519
# Epoch 16/50
# 249/249 [==============================] - 216s 868ms/step - loss: 0.0248 - accuracy: 0.9913 - dice_coef: 0.6076 - mean_io_u: 0.7512 - val_loss: 0.0254 - val_accuracy: 0.9905 - val_dice_coef: 0.6244 - val_mean_io_u: 0.7562
# Epoch 17/50
# 249/249 [==============================] - 216s 868ms/step - loss: 0.0233 - accuracy: 0.9917 - dice_coef: 0.6118 - mean_io_u: 0.7796 - val_loss: 0.0293 - val_accuracy: 0.9909 - val_dice_coef: 0.6036 - val_mean_io_u: 0.8098
# Epoch 18/50
# 249/249 [==============================] - 216s 867ms/step - loss: 0.0236 - accuracy: 0.9916 - dice_coef: 0.6139 - mean_io_u: 0.7630 - val_loss: 0.0235 - val_accuracy: 0.9916 - val_dice_coef: 0.6238 - val_mean_io_u: 0.7936
# Epoch 19/50
# 249/249 [==============================] - 216s 866ms/step - loss: 0.0210 - accuracy: 0.9922 - dice_coef: 0.6210 - mean_io_u: 0.8087 - val_loss: 0.0225 - val_accuracy: 0.9923 - val_dice_coef: 0.6244 - val_mean_io_u: 0.8232
# Epoch 20/50
# 249/249 [==============================] - 216s 868ms/step - loss: 0.0208 - accuracy: 0.9924 - dice_coef: 0.6232 - mean_io_u: 0.8149 - val_loss: 0.0213 - val_accuracy: 0.9926 - val_dice_coef: 0.6214 - val_mean_io_u: 0.8161
# Epoch 21/50
# 249/249 [==============================] - 216s 866ms/step - loss: 0.0202 - accuracy: 0.9926 - dice_coef: 0.6260 - mean_io_u: 0.8061 - val_loss: 0.0229 - val_accuracy: 0.9921 - val_dice_coef: 0.6261 - val_mean_io_u: 0.8277
# Epoch 22/50
# 249/249 [==============================] - 217s 869ms/step - loss: 0.0196 - accuracy: 0.9928 - dice_coef: 0.6317 - mean_io_u: 0.8039 - val_loss: 0.0224 - val_accuracy: 0.9921 - val_dice_coef: 0.6278 - val_mean_io_u: 0.7691
# Epoch 23/50
# 249/249 [==============================] - 219s 878ms/step - loss: 0.0227 - accuracy: 0.9923 - dice_coef: 0.6242 - mean_io_u: 0.7648 - val_loss: 0.0220 - val_accuracy: 0.9921 - val_dice_coef: 0.6419 - val_mean_io_u: 0.7517
# Epoch 24/50
# 249/249 [==============================] - 217s 868ms/step - loss: 0.0189 - accuracy: 0.9930 - dice_coef: 0.6367 - mean_io_u: 0.8195 - val_loss: 0.0232 - val_accuracy: 0.9918 - val_dice_coef: 0.6221 - val_mean_io_u: 0.8161
# Epoch 25/50
# 249/249 [==============================] - 216s 867ms/step - loss: 0.0181 - accuracy: 0.9933 - dice_coef: 0.6438 - mean_io_u: 0.7816 - val_loss: 0.0202 - val_accuracy: 0.9931 - val_dice_coef: 0.6347 - val_mean_io_u: 0.7989
# Epoch 26/50
# 249/249 [==============================] - 216s 867ms/step - loss: 0.0180 - accuracy: 0.9935 - dice_coef: 0.6478 - mean_io_u: 0.8124 - val_loss: 0.0215 - val_accuracy: 0.9926 - val_dice_coef: 0.6534 - val_mean_io_u: 0.8296
# Epoch 27/50
# 249/249 [==============================] - 216s 866ms/step - loss: 0.0172 - accuracy: 0.9937 - dice_coef: 0.6509 - mean_io_u: 0.8222 - val_loss: 0.0220 - val_accuracy: 0.9931 - val_dice_coef: 0.6238 - val_mean_io_u: 0.8702
# Epoch 28/50
# 249/249 [==============================] - 216s 867ms/step - loss: 0.0187 - accuracy: 0.9933 - dice_coef: 0.6506 - mean_io_u: 0.7902 - val_loss: 0.0208 - val_accuracy: 0.9930 - val_dice_coef: 0.6464 - val_mean_io_u: 0.8023
# Epoch 29/50
# 249/249 [==============================] - 216s 868ms/step - loss: 0.0176 - accuracy: 0.9936 - dice_coef: 0.6553 - mean_io_u: 0.8173 - val_loss: 0.0228 - val_accuracy: 0.9929 - val_dice_coef: 0.6486 - val_mean_io_u: 0.8522
# Epoch 30/50
# 249/249 [==============================] - 216s 865ms/step - loss: 0.0162 - accuracy: 0.9941 - dice_coef: 0.6690 - mean_io_u: 0.8221 - val_loss: 0.0206 - val_accuracy: 0.9930 - val_dice_coef: 0.6458 - val_mean_io_u: 0.8303
# Epoch 31/50
# 249/249 [==============================] - 216s 866ms/step - loss: 0.0153 - accuracy: 0.9944 - dice_coef: 0.6741 - mean_io_u: 0.8374 - val_loss: 0.0195 - val_accuracy: 0.9932 - val_dice_coef: 0.6696 - val_mean_io_u: 0.8253
# Epoch 32/50
# 249/249 [==============================] - 219s 878ms/step - loss: 0.0151 - accuracy: 0.9944 - dice_coef: 0.6841 - mean_io_u: 0.8115 - val_loss: 0.0200 - val_accuracy: 0.9933 - val_dice_coef: 0.6499 - val_mean_io_u: 0.8328
# Epoch 33/50
# 249/249 [==============================] - 216s 868ms/step - loss: 0.0155 - accuracy: 0.9943 - dice_coef: 0.6830 - mean_io_u: 0.7900 - val_loss: 0.0208 - val_accuracy: 0.9931 - val_dice_coef: 0.6501 - val_mean_io_u: 0.7780
# Epoch 34/50
# 249/249 [==============================] - 216s 866ms/step - loss: 0.0161 - accuracy: 0.9942 - dice_coef: 0.6832 - mean_io_u: 0.8144 - val_loss: 0.0205 - val_accuracy: 0.9930 - val_dice_coef: 0.6748 - val_mean_io_u: 0.8189
# Epoch 35/50
# 249/249 [==============================] - 216s 868ms/step - loss: 0.0136 - accuracy: 0.9950 - dice_coef: 0.7039 - mean_io_u: 0.8430 - val_loss: 0.0202 - val_accuracy: 0.9936 - val_dice_coef: 0.6631 - val_mean_io_u: 0.8454
# Epoch 36/50
# 249/249 [==============================] - 216s 866ms/step - loss: 0.0142 - accuracy: 0.9948 - dice_coef: 0.7037 - mean_io_u: 0.8280 - val_loss: 0.0204 - val_accuracy: 0.9934 - val_dice_coef: 0.6482 - val_mean_io_u: 0.8587
# Epoch 37/50
# 249/249 [==============================] - 218s 875ms/step - loss: 0.0139 - accuracy: 0.9949 - dice_coef: 0.7065 - mean_io_u: 0.8292 - val_loss: 0.0219 - val_accuracy: 0.9926 - val_dice_coef: 0.6809 - val_mean_io_u: 0.7777
# Epoch 38/50
# 249/249 [==============================] - 216s 867ms/step - loss: 0.0134 - accuracy: 0.9951 - dice_coef: 0.7084 - mean_io_u: 0.8329 - val_loss: 0.0211 - val_accuracy: 0.9932 - val_dice_coef: 0.6570 - val_mean_io_u: 0.8126
# Epoch 39/50
# 249/249 [==============================] - 217s 868ms/step - loss: 0.0130 - accuracy: 0.9952 - dice_coef: 0.7140 - mean_io_u: 0.8470 - val_loss: 0.0263 - val_accuracy: 0.9911 - val_dice_coef: 0.6377 - val_mean_io_u: 0.8073
# Epoch 40/50
# 249/249 [==============================] - 216s 867ms/step - loss: 0.0132 - accuracy: 0.9952 - dice_coef: 0.7177 - mean_io_u: 0.8185 - val_loss: 0.0205 - val_accuracy: 0.9937 - val_dice_coef: 0.6625 - val_mean_io_u: 0.8287
# Epoch 41/50
# 249/249 [==============================] - 217s 868ms/step - loss: 0.0121 - accuracy: 0.9955 - dice_coef: 0.7272 - mean_io_u: 0.8378 - val_loss: 0.0217 - val_accuracy: 0.9937 - val_dice_coef: 0.6688 - val_mean_io_u: 0.8500
#
# Epoch 00041: ReduceLROnPlateau reducing learning rate to 1.9999999494757503e-05.
# Epoch 42/50
# 249/249 [==============================] - 217s 869ms/step - loss: 0.0106 - accuracy: 0.9961 - dice_coef: 0.7431 - mean_io_u: 0.8536 - val_loss: 0.0196 - val_accuracy: 0.9940 - val_dice_coef: 0.6848 - val_mean_io_u: 0.8645
# Epoch 43/50
# 249/249 [==============================] - 216s 866ms/step - loss: 0.0100 - accuracy: 0.9963 - dice_coef: 0.7521 - mean_io_u: 0.8680 - val_loss: 0.0196 - val_accuracy: 0.9939 - val_dice_coef: 0.6857 - val_mean_io_u: 0.8599
# Epoch 44/50
# 249/249 [==============================] - 217s 869ms/step - loss: 0.0098 - accuracy: 0.9964 - dice_coef: 0.7562 - mean_io_u: 0.8714 - val_loss: 0.0199 - val_accuracy: 0.9939 - val_dice_coef: 0.6831 - val_mean_io_u: 0.8782
# Epoch 45/50
# 249/249 [==============================] - 216s 868ms/step - loss: 0.0096 - accuracy: 0.9965 - dice_coef: 0.7598 - mean_io_u: 0.8767 - val_loss: 0.0204 - val_accuracy: 0.9939 - val_dice_coef: 0.6909 - val_mean_io_u: 0.8752
# Epoch 46/50
# 249/249 [==============================] - 217s 871ms/step - loss: 0.0094 - accuracy: 0.9965 - dice_coef: 0.7637 - mean_io_u: 0.8790 - val_loss: 0.0201 - val_accuracy: 0.9940 - val_dice_coef: 0.6865 - val_mean_io_u: 0.8800
# Epoch 47/50
# 249/249 [==============================] - 217s 869ms/step - loss: 0.0093 - accuracy: 0.9966 - dice_coef: 0.7652 - mean_io_u: 0.8814 - val_loss: 0.0203 - val_accuracy: 0.9940 - val_dice_coef: 0.6922 - val_mean_io_u: 0.8831
# Epoch 48/50
# 249/249 [==============================] - 217s 870ms/step - loss: 0.0091 - accuracy: 0.9966 - dice_coef: 0.7691 - mean_io_u: 0.8842 - val_loss: 0.0205 - val_accuracy: 0.9940 - val_dice_coef: 0.6893 - val_mean_io_u: 0.8840
# Epoch 49/50
# 249/249 [==============================] - 217s 871ms/step - loss: 0.0089 - accuracy: 0.9967 - dice_coef: 0.7717 - mean_io_u: 0.8861 - val_loss: 0.0207 - val_accuracy: 0.9940 - val_dice_coef: 0.6898 - val_mean_io_u: 0.8833
# Epoch 50/50
# 249/249 [==============================] - 217s 868ms/step - loss: 0.0088 - accuracy: 0.9967 - dice_coef: 0.7744 - mean_io_u: 0.8872 - val_loss: 0.0212 - val_accuracy: 0.9939 - val_dice_coef: 0.6886 - val_mean_io_u: 0.8910

# %%
unet_baseline.save_weights("unet_baseline_new_best.h5")

# %%
K.clear_session()

unet_baseline_1 = build_unet_baseline(input_layer, ker_init, 0.2)
unet_baseline_1.compile(
    optimizer = tf.keras.optimizers.Adam(learning_rate=1e-04), 
                    loss = 'categorical_crossentropy', 
                    metrics = ["accuracy", dice_coef, tf.metrics.MeanIoU(num_classes=4)]
)

unet_baseline_1.load_weights("unet_baseline_new_best.h5")

# %% [markdown]
# ### Baseline Model Unet 2D after 30 epochs gives 62% dice score (training and validation).
#
# We will be using that model to make further predictions.

# %%
plt.plot(results.history['loss'])
plt.plot(results.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %%
plt.plot(results.history['dice_coef'])
plt.plot(results.history['val_dice_coef'])
plt.title('Dice Metric')
plt.ylabel('Dice_Coefficient')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.subplots_adjust(top=1.00, bottom=0.0, left=0.0, right=0.95, hspace=0.25,
                    wspace=0.35)
plt.show()

# %%
plt.plot(results.history['mean_io_u'])
plt.plot(results.history['val_mean_io_u'])
plt.title('IoU Metric')
plt.ylabel('IoU Coefficient')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.subplots_adjust(top=1.00, bottom=0.0, left=0.0, right=0.95, hspace=0.25,
                    wspace=0.35)
plt.show()

# %%
def vol_pred(case, model_obj):
    z_slices = 120
    z_start = 20
    X = np.empty((z_slices, 128, 128, 4))
    case_path = os.path.join(TRAIN_DATA_PATH, f"BraTS20_Training_{case}")
    
    vol_path = os.path.join(case_path, f'BraTS20_Training_{case}_flair.nii.gz')
    flair=read_image(vol_path)

    vol_path = os.path.join(case_path, f'BraTS20_Training_{case}_t1.nii.gz')
    t1=read_image(vol_path)
    
    vol_path = os.path.join(case_path, f'BraTS20_Training_{case}_t1ce.nii.gz')
    ce=read_image(vol_path)   

    vol_path = os.path.join(case_path, f'BraTS20_Training_{case}_t2.nii.gz')
    t2=read_image(vol_path)

    
    for j in range(z_slices):
        X[j,:,:,0] = cv2.resize(flair[:, :, j + z_start], (128,128))
        X[j,:,:,1] = cv2.resize(ce[:, :, j + z_start], (128,128))
    return model_obj.predict(X/np.max(X), verbose=1)

# %%
case = '011'
case_path = os.path.join(TRAIN_DATA_PATH, f"BraTS20_Training_{case}")

prediction = vol_pred(case, unet_baseline_1)
ground_truth = read_image(os.path.join(case_path, f'BraTS20_Training_{case}_seg.nii.gz'))
# Out:
# 4/4 [==============================] - 0s 48ms/step

# %%
prediction[prediction >= 0.4] = 1
prediction[prediction <0.4] = 0

# %%
core = prediction[:,:,:,1]
edema= prediction[:,:,:,2]
enhancing = prediction[:,:,:,3]



f, axarr = plt.subplots(1,5, figsize = (18, 50)) 
s = 40


axarr[0].imshow(cv2.resize(ground_truth[:,:,s+20], (128, 128)), cmap="gray")
axarr[1].imshow(prediction[s,:,:,1:4], cmap="gray")
axarr[2].imshow(edema[s], cmap="gray")
axarr[3].imshow(core[s], cmap="gray")
axarr[4].imshow(enhancing[s], cmap="gray")

# %%
def show_mask_prediction(model_obj, case: str, slice_: int, onehot_gt: bool = False):
    f, ax = plt.subplots(3, 2, figsize=(30, 40))
    case_path = os.path.join(TRAIN_DATA_PATH, f"BraTS20_Training_{case}")

    image_flair = read_image(os.path.join(case_path, f'BraTS20_Training_{case}_flair.nii.gz'))

    image_ce = read_image(os.path.join(case_path, f'BraTS20_Training_{case}_t1ce.nii.gz'))

    ground_truth = read_image(os.path.join(case_path, f'BraTS20_Training_{case}_seg.nii.gz'))
    
    image_flair = cv2.resize(image_flair, (128, 128))
    image_ce = cv2.resize(image_ce, (128, 128))
    gt = cv2.resize(ground_truth[:, :, slice_+20], (128, 128))
    
    pred_mask = vol_pred(case, model_obj)    # batch_size x 128 x 128 x 3
    
    pred_mask[pred_mask >= 0.4] = 1
    pred_mask[pred_mask <0.4] = 0
    
    
    if onehot_gt:
        gt[gt==4] = 3
        gt = tf.one_hot(gt, 4)
    
    print(gt.shape)
    ax[0][0].imshow(image_flair[:, :, slice_], cmap="gray")
    ax[0][0].set_title("Flair image")
    ax[0][1].imshow(image_flair[:, :, slice_], cmap="gray", interpolation='none')
    ax[0][1].imshow(pred_mask[slice_,:,:,1:4], alpha=0.5, interpolation='none')
    ax[0][1].set_title("Flair image (predicted mask)")
    
    ax[1][0].imshow(image_ce[:, :, slice_], cmap="gray")
    ax[1][0].set_title("t1 ce image")
    ax[1][1].imshow(image_ce[:, :, slice_], cmap="gray", interpolation='none')
    ax[1][1].imshow(pred_mask[slice_,:,:,1:4], alpha=0.5, interpolation='none')
    ax[1][1].set_title("t1 ce image (predicted mask)")
    
    ax[2][0].imshow(image_ce[:, :, slice_], cmap="gray")
    ax[2][0].set_title("Flair image")
    ax[2][1].imshow(image_ce[:, :, slice_], cmap="gray", interpolation='none')
    if onehot_gt:
        ax[2][1].imshow(gt[:, :, 1:4], alpha=0.5, interpolation='none')
    else:
        ax[2][1].imshow(gt, alpha=0.5, interpolation='none')
    ax[2][1].set_title("Flair image (original mask)")

# %%
show_mask_prediction(unet_baseline_1, case='200', slice_=45)
# Out:
# 4/4 [==============================] - 0s 45ms/step
# (128, 128)

# %%
score = unet_baseline_1.evaluate(test_gen)
type(score)
# Out:
# 56/56 [==============================] - 36s 635ms/step - loss: 0.0185 - accuracy: 0.9945 - dice_coef: 0.7102 - mean_io_u: 0.8917
# list

# %%
import pickle

loss = score[0]
acc = score[1]
dice = score[2]
iou = score[3]

test_results = {
    "loss": loss,
    "acc": acc,
    "dice": dice,
    "iou": iou
}

with open("test_results.pkl", 'wb') as fl:
  pickle.dump(test_results, fl, protocol=pickle.HIGHEST_PROTOCOL)

# %%
import random

random_test_idx = random.randint(0, len(test_ids))
test_case = test_ids[random_test_idx]
print(test_case)
test_case = test_case[-3:]

show_mask_prediction(unet_baseline_1, case=test_case, slice_=70)
# Out:
# BraTS20_Training_033
# 4/4 [==============================] - 0s 47ms/step
# (128, 128)
